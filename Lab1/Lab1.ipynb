# %% [markdown]
# # Лабораторна робота №1
#
# ## Підготовка робочого середовища
#
# **Студент:** Софія Посікера
# **Група:** МІТ-31
# **Дата:** 13.09.2026

# %% [markdown]
# ## Мій перший Notebook
#
# Jupyter Notebook дозволяє поєднувати **Python-код**
# та *текстові пояснення*.
#
# ### Основні типи осередків:
#
# - Code
# - Markdown
#
# ### Нумерований список:
#
# 1. Створення Notebook
# 2. Написання коду
# 3. Виконання коду
#
# ### Приклад коду:
#
# `print("Hello, Jupyter!")`

# %%
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %%
student_name = "Софія Посікера"
group = "МІТ-31"

print("Студент:", student_name)
print("Група:", group)
# Out:
# Студент: Софія Посікера
# Група: МІТ-31

# %%
integer_value = 10
float_value = 3.14
text_value = "Data Science"
boolean_value = True

print(integer_value, type(integer_value))
print(float_value, type(float_value))
print(text_value, type(text_value))
print(boolean_value, type(boolean_value))
# Out:
# 10 <class 'int'>
# 3.14 <class 'float'>
# Data Science <class 'str'>
# True <class 'bool'>

# %%
a = 15
b = 4

print("1. Сума:", a + b)
print("2. Різниця:", a - b)
print("3. Добуток:", a * b)
print("4. Ділення:", a / b)
print("5. Ціла частина:", a // b)
print("6. Остача:", a % b)
print("7. Степінь:", a ** b)
# Out:
# 1. Сума: 19
# 2. Різниця: 11
# 3. Добуток: 60
# 4. Ділення: 3.75
# 5. Ціла частина: 3
# 6. Остача: 3
# 7. Степінь: 50625

# %%
values = [10, 20, 30, 40, 50]

print("1. Список:", values)
print("2. Перший елемент:", values[0])
print("3. Останній елемент:", values[-1])
print("4. Кількість елементів:", len(values))

values.append(60)

print("5. Після додавання:", values)
# Out:
# 1. Список: [10, 20, 30, 40, 50]
# 2. Перший елемент: 10
# 3. Останній елемент: 50
# 4. Кількість елементів: 5
# 5. Після додавання: [10, 20, 30, 40, 50, 60]

# %%
import sys

print("Python version:")
print(sys.version)

print("\nPython executable:")
print(sys.executable)
# Out:
# Python version:
# 3.12.5 (tags/v3.12.5:ff3bc82, Aug  6 2024, 20:45:27) [MSC v.1940 64 bit (AMD64)]
#
# Python executable:
# c:\Users\USER\Data_Science_Labs\.venv\Scripts\python.exe

# %%
x = 100

# %%
print(x)
# Out:
# 100

# %% [markdown]
# ## Робота Kernel
#  Після перезапуску Kernel пам'ять очищається, тому змінна x, яку ми створили раніше, більше не існує.Тому під час виконання `print(x)` виникла помилка `NameError`.
#
# Це відбувається тому, що Kernel зберігає змінні та стан програми
# в оперативній пам'яті. Після його перезапуску цей стан очищується.
